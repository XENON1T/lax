# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import lax
import pandas as pd

# %%
data = pd.read_pickle('/project/lgrandi/xenon1t/data/180306/pruned/all_cuts/none_SR0_pax6.8.0_hax2.4.0_lax1.5.1_cs1LT200_fv1_cuts1_pruned.pkl')

# %%
df = lax.lichens.postsr1.ERBandDEC().process(data)

# %%
for switch in True, False:
    d = df[df.CutERBandDEC ^ switch]
    plt.scatter(d.cs1, d.cs2,
                color='red' if switch else 'blue')
plt.xlabel("cS1")
plt.ylabel("log10(cs2/cs1)")

# %% [markdown]
# Blue = passed, Red = Failed
